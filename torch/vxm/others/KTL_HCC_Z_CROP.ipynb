# %%
import os
import numpy as np
import nibabel

from tqdm import tqdm
from data_preparation.utils import crop_non_zero_3d
import scipy.ndimage as ndimage

# %%
root_path = "/media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation"
save_root_path = "/media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Z_CROP_V2"
save_anom_root_path = "/media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Z_CROP_ANOM"

sub_paths = [root_path + f"/{sub_dir}" for sub_dir in os.listdir(root_path)]

mask_str = "output/li.nii"
scan_str = "input/li_0000.nii"

all_pre_mask_path = []
all_portal_mask_path = []
all_pre_path = []
all_portal_path = []


for idx, sub_path in enumerate(sub_paths):

    if "P" in os.listdir(sub_path):
        continue
    else:
        pre_phase_path = sub_path + "/D/"
        portal_phase_path = sub_path + "/V/"

        pre_mask_path = pre_phase_path + mask_str
        pre_path = pre_phase_path + scan_str

        portal_mask_path = portal_phase_path + mask_str
        portal_path = portal_phase_path + scan_str

        all_pre_mask_path.append(pre_mask_path)
        all_portal_mask_path.append(portal_mask_path)
        all_pre_path.append(pre_path)
        all_portal_path.append(portal_path)
# sort paths
all_pre_mask_path = sorted(all_pre_mask_path)
all_portal_mask_path = sorted(all_portal_mask_path)
all_pre_path = sorted(all_pre_path)
all_portal_path = sorted(all_portal_path)

list_A = []
list_B = []
for p in range(len(all_pre_mask_path)):
    print(f"D out: {all_pre_mask_path[p]}, P out: {all_portal_mask_path[p]}")
    print(f"D in: {all_pre_path[p]}, P in: {all_portal_path[p]}")
    list_A.append(all_portal_path[p].split("/")[7])
    list_B.append(all_portal_path[p].split("/")[7])
# print(list_A)
# print(list_B)
set_A = set(list_A)
set_B = set(list_B)
print(set_A.symmetric_difference(set_B))
# Out:
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1104/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1104/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1104/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1104/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1106/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1106/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1106/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1106/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1107/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1107/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1107/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1107/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1109/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1109/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1109/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1109/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1110/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1110/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1110/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1110/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1114/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1114/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1114/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1114/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1117/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1117/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1117/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1117/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1121/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1121/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1121/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1121/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1122/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1122/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1122/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1122/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1123/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1123/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1123/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1123/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1130/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1130/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1130/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1130/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1131/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1131/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1131/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1131/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1142/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1142/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1142/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1142/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1147/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1147/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1147/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1147/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1157/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1157/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1157/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1157/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1166/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1166/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1166/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1166/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1168/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1168/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1168/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1168/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1171/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1171/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1171/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1171/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1176/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1176/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1176/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1176/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1179/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1179/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1179/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1179/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1181/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1181/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1181/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1181/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1186/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1186/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1186/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1186/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1189/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1189/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1189/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1189/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1191/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1191/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1191/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1191/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1194/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1194/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1194/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1194/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1197/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1197/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1197/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1197/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1198/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1198/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1198/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1198/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1202/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1202/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1202/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1202/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1204/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1204/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1204/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1204/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1212/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1212/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1212/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1212/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1213/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1213/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1213/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1213/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1214/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1214/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1214/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1214/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1220/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1220/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1220/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1220/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1221/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1221/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1221/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1221/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1223/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1223/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1223/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1223/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1229/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1229/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1229/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1229/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1231/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1231/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1231/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1231/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1233/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1233/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1233/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1233/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1248/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1248/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1248/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1248/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1250/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1250/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1250/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1250/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1253/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1253/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1253/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1253/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1260/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1260/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1260/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1260/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1261/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1261/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1261/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1261/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1264/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1264/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1264/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1264/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1265/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1265/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1265/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1265/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1268/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1268/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1268/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1268/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1276/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1276/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1276/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1276/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1285/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1285/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1285/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1285/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1289/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1289/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1289/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1289/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1290/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1290/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1290/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1290/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1297/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1297/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1297/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1297/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1303/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1303/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1303/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1303/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1308/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1308/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1308/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1308/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1310/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1310/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1310/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1310/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1317/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1317/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1317/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1317/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1318/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1318/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1318/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1318/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1319/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1319/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1319/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1319/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1321/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1321/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1321/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1321/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1323/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1323/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1323/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1323/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1328/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1328/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1328/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1328/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1329/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1329/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1329/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1329/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1331/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1331/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1331/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1331/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1334/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1334/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1334/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1334/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1339/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1339/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1339/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1339/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1345/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1345/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1345/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1345/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1346/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1346/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1346/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1346/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1348/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1348/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1348/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1348/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1353/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1353/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1353/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1353/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1359/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1359/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1359/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1359/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1363/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1363/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1363/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1363/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1365/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1365/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1365/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1365/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1367/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1367/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1367/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1367/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1369/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1369/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1369/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1369/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1370/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1370/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1370/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1370/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1381/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1381/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1381/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1381/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1387/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1387/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1387/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1387/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1399/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1399/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1399/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1399/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1400/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1400/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1400/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1400/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1402/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1402/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1402/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1402/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1403/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1403/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1403/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1403/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1412/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1412/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1412/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1412/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1413/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1413/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1413/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1413/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1418/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1418/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1418/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1418/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1421/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1421/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1421/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1421/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1428/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1428/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1428/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1428/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1431/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1431/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1431/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1431/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1433/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1433/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1433/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1433/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1434/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1434/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1434/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1434/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1437/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1437/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1437/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1437/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1442/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1442/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1442/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1442/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1445/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1445/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1445/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1445/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1448/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1448/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1448/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1448/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1449/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1449/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1449/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1449/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1464/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1464/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1464/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1464/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1465/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1465/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1465/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1465/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1466/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1466/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1466/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1466/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1484/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1484/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1484/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1484/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1485/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1485/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1485/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1485/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1498/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1498/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1498/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1498/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1499/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1499/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1499/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1499/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1504/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1504/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1504/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1504/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1505/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1505/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1505/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1505/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1508/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1508/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1508/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1508/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1513/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1513/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1513/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1513/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1514/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1514/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1514/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1514/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1518/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1518/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1518/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1518/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1524/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1524/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1524/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1524/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1526/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1526/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1526/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1526/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1528/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1528/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1528/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1528/V/input/li_0000.nii
# ...
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1635/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1635/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1635/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1635/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1638/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1638/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1638/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1638/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1639/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1639/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1639/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1639/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1647/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1647/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1647/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1647/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1649/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1649/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1649/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1649/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1659/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1659/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1659/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1659/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1665/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1665/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1665/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1665/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1667/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1667/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1667/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1667/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1674/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1674/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1674/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1674/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1676/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1676/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1676/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1676/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1689/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1689/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1689/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1689/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1690/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1690/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1690/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1690/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1693/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1693/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1693/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1693/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1703/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1703/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1703/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1703/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1705/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1705/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1705/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1705/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1708/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1708/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1708/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1708/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1712/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1712/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1712/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1712/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1713/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1713/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1713/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1713/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1716/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1716/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1716/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1716/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1717/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1717/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1717/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1717/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1723/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1723/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1723/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1723/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1728/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1728/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1728/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1728/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1730/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1730/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1730/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1730/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1731/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1731/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1731/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1731/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1732/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1732/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1732/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1732/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1749/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1749/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1749/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1749/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1750/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1750/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1750/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1750/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1759/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1759/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1759/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1759/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1762/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1762/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1762/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1762/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1769/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1769/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1769/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1769/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1773/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1773/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1773/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1773/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1774/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1774/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1774/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1774/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1778/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1778/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1778/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1778/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1781/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1781/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1781/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1781/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1799/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1799/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1799/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1799/V/input/li_0000.nii
# D out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1800/D/output/li.nii, P out: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1800/V/output/li.nii
# D in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1800/D/input/li_0000.nii, P in: /media/monib/External Disk/work2022/Base_Dataset/KTL_HCC_Dicom_Segmentation/HCC_1800/V/input/li_0000.nii
# set()

# %%
def ensure_multiples_of_16(image_3d):
    """
    Ensures that the input image shape is multiple of 16
    image_3d: numpy 3d array
    """

    multiples_of_16 = [16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304, 320,
                       336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512, 528, 544, 560, 576, 592, 608, 624,
                       640, 656, 672, 688, 704, 720, 736, 752, 768, 784]

    # img_cropped_3d = crop_non_zero_3d(image_3d)
    img_cropped_3d = image_3d

    new_dimension = [img_cropped_3d.shape[0], img_cropped_3d.shape[1], img_cropped_3d.shape[2]]  # x, y , z

    for d in range(len(new_dimension)):
        if img_cropped_3d.shape[d] not in multiples_of_16:
            for m in multiples_of_16:
                if m > img_cropped_3d.shape[d]:
                    new_dimension[d] = m
                    break
    padding = np.array(new_dimension) - np.array(img_cropped_3d.shape)

    new_pad = []
    for pad in padding:
        if pad % 2 == 0:  # the number is even
            p1 = pad // 2
            p2 = pad // 2
            new_pad.append((p1, p2))
        else:  # the number is odd
            p1 = int((pad - 1) / 2)  # (5 - 1) / 2 = 2
            p2 = int(((pad - 1) / 2) + 1)  # (5 - 1)/ 2 => 2 + 1 = 3
            new_pad.append((p1, p2))

    padded_3d = np.pad(img_cropped_3d, new_pad, 'constant', constant_values=(-1000, -1000))
    return padded_3d

# %%
def match_spatial_size(image_3d_A, image_3d_B):
    # -------------------- Make sure the spatial size of images matches each other --------------------
    # move this part to data preprocessing section
    if image_3d_A.shape[0] < image_3d_B.shape[0]:
        image_3d_A = np.pad(image_3d_A, ((0, abs(image_3d_B.shape[0] - image_3d_A.shape[0])),
                                         (0, 0), (0, 0)), 'constant',  constant_values=(-1000, -1000))

    if image_3d_A.shape[0] > image_3d_B.shape[0]:
        image_3d_B = np.pad(image_3d_B, ((0, abs(image_3d_B.shape[0] - image_3d_A.shape[0])),
                                         (0, 0), (0, 0)), 'constant',  constant_values=(-1000, -1000))

    if image_3d_A.shape[1] < image_3d_B.shape[1]:
        image_3d_A = np.pad(image_3d_A, ((0, 0),
                                         (0, abs(image_3d_B.shape[1] - image_3d_A.shape[1])), (0, 0)), 'constant',  constant_values=(-1000, -1000))

    if image_3d_A.shape[1] > image_3d_B.shape[1]:
        image_3d_B = np.pad(image_3d_B, ((0, 0),
                                         (0, abs(image_3d_B.shape[1] - image_3d_A.shape[1])), (0, 0)), 'constant',  constant_values=(-1000, -1000))

    if image_3d_A.shape[2] < image_3d_B.shape[2]:
        image_3d_A = np.pad(image_3d_A, ((0, 0),
                                         (0, 0), (0, abs(image_3d_B.shape[2] - image_3d_A.shape[2]))), 'constant',  constant_values=(-1000, -1000))

    if image_3d_A.shape[2] > image_3d_B.shape[2]:
        image_3d_B = np.pad(image_3d_B, ((0, 0),
                                         (0, 0), (0, abs(image_3d_B.shape[2] - image_3d_A.shape[2]))), 'constant',  constant_values=(-1000, -1000))

    return image_3d_A, image_3d_B

# %%
slice_thresh = 112

for i in tqdm(range(len(all_pre_path))):

    # save dir
    pre_str = "/delayed/"
    portal_str = "/portal/"
    anom_str_d = "/anomaly_d/"
    anom_str_p = "/anomaly_p/"
    save_dir_pre = all_pre_path[i].split("/")[7]
    save_dir_portal = all_portal_path[i].split("/")[7]

    save_pre_path = save_root_path + pre_str + save_dir_pre + "_d"
    save_portal_path = save_root_path + portal_str + save_dir_portal + "_p"
    save_anom_d_path = save_anom_root_path + anom_str_d + save_dir_portal + "_anom_d"
    save_anom_p_path = save_anom_root_path + anom_str_p + save_dir_portal + "_anom_p"



    # pre part
    pre_scan = nibabel.load(all_pre_path[i])
    pre_scan_array = pre_scan.get_fdata()

    # pre masks
    pre_mask_file = nibabel.load(all_pre_mask_path[i])
    pre_mask_array = pre_mask_file.get_fdata()
    pre_mask_array[pre_mask_array == 2] = 1

    # cropped_pre_mask_array = crop_non_zero_3d(pre_mask_array)

    indices_3d_pre = np.nonzero(pre_mask_array)
    xyz_min_pre = np.min(indices_3d_pre, 1)
    xyz_max_pre = np.max(indices_3d_pre, 1)

    cropped_pre_scan= pre_scan_array[: , : , xyz_min_pre[2]:xyz_max_pre[2]]
    # pre_mask_m16 = ensure_multiples_of_16(cropped_pre_mask_array)
    pre_scan_m16 = ensure_multiples_of_16(cropped_pre_scan)

    # pre_mask_matched, pre_scan_matched = match_spatial_size(pre_mask_m16, pre_scan_m16)

    # pre_scan_new = pre_scan_matched * ndimage.binary_fill_holes(pre_mask_matched)


    # portal part
    portal_scan = nibabel.load(all_portal_path[i])
    portal_scan_array = portal_scan.get_fdata()

    # portal masks
    portal_mask_file = nibabel.load(all_portal_mask_path[i])
    portal_mask_array = portal_mask_file.get_fdata()
    portal_mask_array[portal_mask_array == 2] = 1

    # cropped_portal_mask_array = crop_non_zero_3d(portal_mask_array)

    indices_3d_portal = np.nonzero(portal_mask_array)
    xyz_min_portal = np.min(indices_3d_portal, 1)
    xyz_max_portal = np.max(indices_3d_portal, 1)

    cropped_portal_scan= portal_scan_array[: , :, xyz_min_portal[2]:xyz_max_portal[2]]

    # portal_mask_m16 = ensure_multiples_of_16(cropped_portal_mask_array)
    portal_scan_m16 = ensure_multiples_of_16(cropped_portal_scan)

    # ensure equal shape size
    # portal_mask_matched, portal_scan_matched = match_spatial_size(portal_mask_m16, portal_scan_m16)

    # portal_scan_new = portal_scan_matched * ndimage.binary_fill_holes(portal_mask_matched)

    matched_pre, matched_portal = match_spatial_size(pre_scan_m16, portal_scan_m16)

    if matched_pre.shape[2] > slice_thresh:
        print(f"matched_pre.shape[2]: {matched_pre.shape[2]}")
        os.makedirs(save_anom_d_path , exist_ok=True)
        os.makedirs(save_anom_p_path , exist_ok=True)

        save_anom_d_nifti_path = os.path.join(save_anom_d_path, f"crop_z_001.nii")
        nifti_pre_new = nibabel.Nifti1Image(matched_pre, pre_scan.affine, pre_scan.header)
        nibabel.save(nifti_pre_new, save_anom_d_nifti_path)

        save_anom_p_nifti_path = os.path.join(save_anom_p_path, f"crop_z_001.nii")
        nifti_portal_new = nibabel.Nifti1Image(matched_portal, portal_scan.affine, portal_scan.header)
        nibabel.save(nifti_portal_new, save_anom_p_nifti_path)

    else:

        os.makedirs(save_pre_path , exist_ok=True)    # pre scans
        os.makedirs(save_portal_path , exist_ok=True)    # portal scans

        save_pre_nifti_path = os.path.join(save_pre_path, f"crop_z_001.nii")
        nifti_pre_new = nibabel.Nifti1Image(matched_pre, pre_scan.affine, pre_scan.header)
        nibabel.save(nifti_pre_new, save_pre_nifti_path)

        save_portal_nifti_path = os.path.join(save_portal_path, f"crop_z_001.nii")
        nifti_portal_new = nibabel.Nifti1Image(matched_portal, portal_scan.affine, portal_scan.header)
        nibabel.save(nifti_portal_new, save_portal_nifti_path)
    # if i==4:
    #     break
print('save completed!')
# Out:
#   0%|          | 0/168 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_57558/149851952.py in <module>
#      29     # cropped_pre_mask_array = crop_non_zero_3d(pre_mask_array)
#      30
# ---> 31     indices_3d_pre = np.nonzero(pre_mask_array)
#      32     xyz_min_pre = np.min(indices_3d_pre, 1)
#      33     xyz_max_pre = np.max(indices_3d_pre, 1)
#
# <__array_function__ internals> in nonzero(*args, **kwargs)
#
# ~/anaconda3/envs/voxelmorph/lib/python3.7/site-packages/numpy/core/fromnumeric.py in nonzero(a)
#    1919
#    1920     """
# -> 1921     return _wrapfunc(a, 'nonzero')
#    1922
#    1923
#
# ~/anaconda3/envs/voxelmorph/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:
